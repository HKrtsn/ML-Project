# %%
import sys
sys.path.append("../preprocessing")
from transform import transform_log_scale, pca, cluster_dbscan, df, visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cluster_dbscan(df)
# Out:
# PC1: 31.86%, PC2: 22.27%, PC3: 19.71%,  Total: 73.84%
#                   PC1       PC2       PC3
# DrivAge_log -0.672595  0.029320 -0.120935
# VehPower    -0.144599  0.155265  0.975303
# VehAge_log   0.161456 -0.685714  0.167150
# Density_log  0.163178  0.708447 -0.051523
# BonusMalus   0.688485  0.054149  0.059708
# 25
